# %%
import os
from dotenv import load_dotenv

# Load environment variables from a .env file
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
groq_llm = ChatGroq(model="llama-3.3-70b-versatile")
result = groq_llm.invoke("Hi my name is Deepak, what is your name?")
print(result.content)
# Out:
# Hello Deepak, I'm an AI assistant, and I don't have a personal name. I'm here to help answer your questions and provide information on a wide range of topics. How can I assist you today?

# %%
### Prompt Engineering
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an AI Enginneering expert. Provide me answer based on the question."),
        ("user", "{input}"),
    ]
)
prompt

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model="gemma2-9b-it")
model

# %%
### chaning the model
chain =prompt| model
chain

# %%
response = chain.invoke({"input": "Can you tell me something about langsmith"})
print(response.content)

# %%
chain = prompt | model | output_parser
response = chain.invoke({"query": "Can you tell me something about langsmith"})
print(response)
